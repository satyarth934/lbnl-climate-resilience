# %% [markdown]
# ---

# %%
import geopandas as gpd

site_json_file_path = "../../data/LMsites.json"
sites = gpd.read_file(site_json_file_path)

print(sites.shape)
sites
# Out:
# (104, 21)
#      OBJECTID   ID  TransferYear                       Directory  \
# 0           1    1          1998        \NM\AmbrosiaLakeDisposal
# 1           2    2          2008                    \AK\Amchitka
# 2           3    3          2004               \NM\L-BarDisposal
# 3           4    4          1997           \NM\BluewaterDisposal
# 4           5    5          2004  \PR\BONUSDecommissionedReactor
# ..        ...  ...           ...                             ...
# 99       1265  100          2019                      \CO\Bronco
# 100      1266  101          2019              \ID\Pre-SchoonerII
# 101      1267  102          2019      \MT\Pre-GondolaandTrencher
# 102      1268  103          2019                        \UT\Utah
# 103      1670  106          2020            \NV\TonopahTestRange
#
#                                           FactSheetUrl  ZoomLevel   Latitude  \
# 0    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         15  35.408798
# 1    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         13  51.436583
# 2    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         15  35.187651
# 3    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         14  35.270623
# 4    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         18  18.364744
# ..                                                 ...        ...        ...
# 99                                                             16  40.047970
# 100                                                            17  42.401041
# 101                                                            15  47.928214
# 102                                                            18  39.985497
# 103  https://www.energy.gov/sites/prod/files/2020/0...         11  37.886032
#
#       Longitude                                    Name NameMnemonic  ...  \
# 0   -107.799285        Ambrosia Lake, NM, Disposal Site          AMB  ...
# 1    179.179778                      Amchitka, AK, Site          AMC  ...
# 2   -107.334722                L-Bar, NM, Disposal Site          BAR  ...
# 3   -107.947483            Bluewater, NM, Disposal Site          BLU  ...
# 4    -67.268557  BONUS, PR, Decommissioned Reactor Site          BON  ...
# ..          ...                                     ...          ...  ...
# 99  -108.368585                        Bronco, CO, Site          BRO  ...
# 100 -115.575696               Pre-Schooner II, ID, Site          PSC  ...
# 101 -106.649242      Pre-Gondola and Trencher, MT, Site          PGD  ...
# 102 -109.611552                          Utah, UT, Site          UTA  ...
# 103 -116.762188            Tonopah Test Range, NV, Site          TTR  ...
#
#                                       PublicWebpageUrl      RegulatoryDriver  \
# 0    https://www.energy.gov/lm/ambrosia-lake-new-me...        UMTRCA Title I
# 1       https://www.energy.gov/lm/amchitka-alaska-site       Nevada Offsites
# 2    https://www.energy.gov/lm/l-bar-new-mexico-dis...       UMTRCA Title II
# 3    https://www.energy.gov/lm/bluewater-new-mexico...       UMTRCA Title II
# 4    https://www.energy.gov/lm/bonus-puerto-rico-de...                   D&D
# ..                                                 ...                   ...
# 99   https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 100  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 101  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 102  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 103  https://www.energy.gov/lm/tonopah-test-range-n...       Nevada Offsites
#
#     MaintenanceCategory SiteCoordSysWkid  SiteCoordSysWkt AvailableOnWeb  \
# 0                     2             6318                               Y
# 1                     2           102640                               Y
# 2                     2             6318                               Y
# 3                     2             6318                               Y
# 4                     2               -1                               Y
# ..                  ...              ...              ...            ...
# 99                    2             6318                               Y
# 100                   1               -1                               Y
# 101                   2               -1                               Y
# 102                   2               -1                               Y
# 103                   2               -1                               Y
#
#                              ShortName    LastUpdated        LastRun  \
# 0          Ambrosia Lake Disposal Site  1618441514000  1620430062000
# 1                        Amchitka Site  1603926315000  1620430190000
# 2                  L-Bar Disposal Site  1611875114000  1620429262000
# 3              Bluewater Disposal Site  1603926315000  1620429265000
# 4    BONUS Decommissioned Reactor Site  1620428720000  1620430708000
# ..                                 ...            ...            ...
# 99                         Bronco Site  1620428720000  1620430711000
# 100               Pre-Schooner II Site  1620428720000  1620430711000
# 101      Pre-Gondola and Trencher Site  1620428720000  1620430711000
# 102                          Utah Site  1620428720000  1620430711000
# 103            Tonopah Test Range Site  1620428720000  1620430711000
#
#                               geometry
# 0    POINT (-12000161.514 4219574.869)
# 1     POINT (19946201.647 6698886.591)
# 2    POINT (-11948446.598 4189411.496)
# 3    POINT (-12016658.840 4200718.815)
# 4     POINT (-7488301.512 2080285.691)
# ..                                 ...
# 99   POINT (-12063535.755 4872915.660)
# 100  POINT (-12865827.613 5221244.015)
# 101  POINT (-11872139.288 6094920.432)
# 102  POINT (-12201902.134 4863834.896)
# 103  POINT (-12997907.312 4563338.443)
#
# [104 rows x 21 columns]

# %%
import importlib
from climate_resilience import downloader as dd

importlib.reload(dd)

output_dir = "gee_downloader_testing"    # Folder located in Google Drive. Will be created if not already present.
site_json_file_path = "../../../data/LMsites.json"
yaml_path = "../scripts/download_params.yml"

sd_obj = dd.SitesDownloader(
    folder=output_dir,
    site_json_file_path=site_json_file_path,
    # latitude_range=(30, 50),
    longitude_range=(-150, -120),
)

print(sd_obj.sites.shape)
# Out:
# (5, 21)

# %%
sd_obj.sites
# Out:
#     OBJECTID  ID  TransferYear                                      Directory  \
# 23        24  24          1995                           \OR\LakeviewDisposal
# 24        25  25          1995                         \OR\LakeviewProcessing
# 60        61  61          1993                                     \OR\Albany
# 63        64  64          1985                                   \CA\Berkeley
# 91       463  92          2006  \CA\LaboratoryforEnergy-RelatedHealthResearch
#
#                                          FactSheetUrl  ZoomLevel   Latitude  \
# 23  https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         16  42.285784
# 24  https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         15  42.210080
# 60  https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         14  44.620210
# 63  https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         14  37.872630
# 91  https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         14  38.519166
#
#      Longitude                                               Name  \
# 23 -120.433462                        Lakeview, OR, Disposal Site
# 24 -120.363670                      Lakeview, OR, Processing Site
# 60 -123.120800                                   Albany, OR, Site
# 63 -122.256290                                 Berkeley, CA, Site
# 91 -121.755111  Laboratory for Energy-Related Health Research,...
#
#    NameMnemonic  ...                                   PublicWebpageUrl  \
# 23          LKD  ...  https://www.energy.gov/lm/lakeview-oregon-disp...
# 24          LKP  ...  https://www.energy.gov/lm/lakeview-oregon-disp...
# 60          AOR  ...      https://www.energy.gov//lm/albany-oregon-site
# 63          BCA  ...  https://www.energy.gov/lm/berkeley-california-...
# 91          LEH  ...  https://www.energy.gov/lm/laboratory-energy-re...
#
#    RegulatoryDriver MaintenanceCategory SiteCoordSysWkid  SiteCoordSysWkt  \
# 23   UMTRCA Title I                   2             6318
# 24   UMTRCA Title I                   2             6318
# 60           FUSRAP                   1               -1
# 63           FUSRAP                   1               -1
# 91      CERCLA/RCRA                   2           102642
#
#    AvailableOnWeb                                          ShortName  \
# 23              Y                             Lakeview Disposal Site
# 24              Y                           Lakeview Processing Site
# 60              Y                                        Albany Site
# 63              Y                                      Berkeley Site
# 91              Y  Laboratory for Energy-Related Health Research ...
#
#       LastUpdated        LastRun                           geometry
# 23  1615331118000  1620430205000  POINT (-13406591.664 5203885.098)
# 24  1615244724000  1620430203000  POINT (-13398822.454 5192500.541)
# 60  1620428720000  1620430708000  POINT (-13705744.762 5561928.180)
# 63  1620428720000  1620430708000  POINT (-13609507.949 4561448.296)
# 91  1603926315000  1620430205000  POINT (-13553716.958 4653028.403)
#
# [5 rows x 21 columns]

# %%
sd_obj.sites
# Out:
#      OBJECTID   ID  TransferYear                       Directory  \
# 0           1    1          1998        \NM\AmbrosiaLakeDisposal
# 1           2    2          2008                    \AK\Amchitka
# 2           3    3          2004               \NM\L-BarDisposal
# 3           4    4          1997           \NM\BluewaterDisposal
# 4           5    5          2004  \PR\BONUSDecommissionedReactor
# ..        ...  ...           ...                             ...
# 99       1265  100          2019                      \CO\Bronco
# 100      1266  101          2019              \ID\Pre-SchoonerII
# 101      1267  102          2019      \MT\Pre-GondolaandTrencher
# 102      1268  103          2019                        \UT\Utah
# 103      1670  106          2020            \NV\TonopahTestRange
#
#                                           FactSheetUrl  ZoomLevel   Latitude  \
# 0    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         15  35.408798
# 1    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         13  51.436583
# 2    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         15  35.187651
# 3    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         14  35.270623
# 4    https://www.lm.doe.gov/WorkArea/linkit.aspx?Li...         18  18.364744
# ..                                                 ...        ...        ...
# 99                                                             16  40.047970
# 100                                                            17  42.401041
# 101                                                            15  47.928214
# 102                                                            18  39.985497
# 103  https://www.energy.gov/sites/prod/files/2020/0...         11  37.886032
#
#       Longitude                                    Name NameMnemonic  ...  \
# 0   -107.799285        Ambrosia Lake, NM, Disposal Site          AMB  ...
# 1    179.179778                      Amchitka, AK, Site          AMC  ...
# 2   -107.334722                L-Bar, NM, Disposal Site          BAR  ...
# 3   -107.947483            Bluewater, NM, Disposal Site          BLU  ...
# 4    -67.268557  BONUS, PR, Decommissioned Reactor Site          BON  ...
# ..          ...                                     ...          ...  ...
# 99  -108.368585                        Bronco, CO, Site          BRO  ...
# 100 -115.575696               Pre-Schooner II, ID, Site          PSC  ...
# 101 -106.649242      Pre-Gondola and Trencher, MT, Site          PGD  ...
# 102 -109.611552                          Utah, UT, Site          UTA  ...
# 103 -116.762188            Tonopah Test Range, NV, Site          TTR  ...
#
#                                       PublicWebpageUrl      RegulatoryDriver  \
# 0    https://www.energy.gov/lm/ambrosia-lake-new-me...        UMTRCA Title I
# 1       https://www.energy.gov/lm/amchitka-alaska-site       Nevada Offsites
# 2    https://www.energy.gov/lm/l-bar-new-mexico-dis...       UMTRCA Title II
# 3    https://www.energy.gov/lm/bluewater-new-mexico...       UMTRCA Title II
# 4    https://www.energy.gov/lm/bonus-puerto-rico-de...                   D&D
# ..                                                 ...                   ...
# 99   https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 100  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 101  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 102  https://www.energy.gov/lm/plowsharevela-unifor...  PlowshareVelaUniform
# 103  https://www.energy.gov/lm/tonopah-test-range-n...       Nevada Offsites
#
#     MaintenanceCategory SiteCoordSysWkid  SiteCoordSysWkt AvailableOnWeb  \
# 0                     2             6318                               Y
# 1                     2           102640                               Y
# 2                     2             6318                               Y
# 3                     2             6318                               Y
# 4                     2               -1                               Y
# ..                  ...              ...              ...            ...
# 99                    2             6318                               Y
# 100                   1               -1                               Y
# 101                   2               -1                               Y
# 102                   2               -1                               Y
# 103                   2               -1                               Y
#
#                              ShortName    LastUpdated        LastRun  \
# 0          Ambrosia Lake Disposal Site  1618441514000  1620430062000
# 1                        Amchitka Site  1603926315000  1620430190000
# 2                  L-Bar Disposal Site  1611875114000  1620429262000
# 3              Bluewater Disposal Site  1603926315000  1620429265000
# 4    BONUS Decommissioned Reactor Site  1620428720000  1620430708000
# ..                                 ...            ...            ...
# 99                         Bronco Site  1620428720000  1620430711000
# 100               Pre-Schooner II Site  1620428720000  1620430711000
# 101      Pre-Gondola and Trencher Site  1620428720000  1620430711000
# 102                          Utah Site  1620428720000  1620430711000
# 103            Tonopah Test Range Site  1620428720000  1620430711000
#
#                               geometry
# 0    POINT (-12000161.514 4219574.869)
# 1     POINT (19946201.647 6698886.591)
# 2    POINT (-11948446.598 4189411.496)
# 3    POINT (-12016658.840 4200718.815)
# 4     POINT (-7488301.512 2080285.691)
# ..                                 ...
# 99   POINT (-12063535.755 4872915.660)
# 100  POINT (-12865827.613 5221244.015)
# 101  POINT (-11872139.288 6094920.432)
# 102  POINT (-12201902.134 4863834.896)
# 103  POINT (-12997907.312 4563338.443)
#
# [104 rows x 21 columns]

# %%
'1' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4f/fztycq7j0wj0t_2bhzck543c0000gp/T/ipykernel_6122/268881832.py in <module>
# ----> 1 '1' + 3
#
# TypeError: can only concatenate str (not "int") to str
